# %%
import pandas as pd

df=pd.read_csv('score.csv',index_col='지원번호')
# 데이터 추가
df['합계'] = df['국어']+df['영어']+df['수학']+df['사회']
df['평균'] = df['합계']/4
df['결과']= 'Fail'
df
# Out:
#        이름   학교    키   국어   영어   수학  사회        SW특기   합계     평균    결과
# 지원번호
# 1번    강나래  구로고  197   90   85  100  85      Python  360  90.00  Fail
# 2번    강태원  구로고  184   40   35   50  25        Java  150  37.50  Fail
# 3번    강호림  가산고  168   80   75   70  75  Javascript  300  75.00  Fail
# 4번    김수찬  구로고  187   40   60   70  80         NaN  250  62.50  Fail
# 5번    김재욱  가산고  188   15   20   10  10         NaN   55  13.75  Fail
# 6번    박동현  가산고  202   80  100   95  80           C  355  88.75  Fail
# 7번    박혜정  구로고  188   55   65   45  35      PYTHON  200  50.00  Fail
# 8번    승근열  구로고  190  100   85   90  95          C#  370  92.50  Fail

# %%
# 데이터 추가
df['합계'] = df['국어']+df['영어']+df['수학']+df['사회']

# %% [markdown]
# 컬럼 순서 변경

# %%
df.columns
# Out:
# pandas.core.indexes.base.Index

# %%
cols[1:-1] # list타입
cols[-1] # 문자열 타입
# Out:
# '결과'

# %%
cols = list(df.columns)
# df[df.columns]
# df[이름, 평균, 학교 : 결과]
df = df[[cols[0]]+[cols[-1]]+cols[1:-1]]
df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 cols = list(df.columns)
#       2 # df[df.columns]
#       3 # df[이름, 평균, 학교 : 결과]
#       4 df = df[[cols[0]]+[cols[-1]]+cols[1:-1]]
#
# File c:\python\Lib\site-packages\pandas\core\generic.py:6299, in NDFrame.__getattr__(self, name)
#    6292 if (
#    6293     name not in self._internal_names_set
#    6294     and name not in self._metadata
#    6295     and name not in self._accessors
#    6296     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297 ):
#    6298     return self[name]
# -> 6299 return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'columns'

# %%
cols = list(df.columns)
cols
# Out:
# ['이름', '학교', '키', '국어', '영어', '수학', '사회', 'SW특기', '합계', '평균', '결과']

# %%
cols = list(df.columns)
df= df[[cols[0]]+[cols[2]]+[cols[-1]]+[cols[1]]+cols[3:-1]]
df.head(3)
# Out:
#        이름    키    결과   학교  국어  영어   수학  사회        SW특기   합계    평균
# 지원번호
# 1번    강나래  197  Fail  구로고  90  85  100  85      Python  360  90.0
# 2번    강태원  184  Fail  구로고  40  35   50  25        Java  150  37.5
# 3번    강호림  168  Fail  가산고  80  75   70  75  Javascript  300  75.0

# %%
import pandas as pd

df=pd.read_csv('score.csv',index_col='지원번호')
cols = list(df.columns)
cols
# Out:
# ['이름', '학교', '키', '국어', '영어', '수학', '사회', 'SW특기']

# %% [markdown]
# 컬럼 이름 변경

# %%
# 컬럼 전체 이름 변경
df.columns =['name','school','height','kor','eng','math','society','sw']

# 컬럼의 이름 변경 , inplace = True 반영
df.rename(columns={'이름':'name','학교':'school'})
df
df.rename(index={'1번':'no1'})
# Out:
#        이름   학교    키   국어   영어   수학  사회        SW특기
# 지원번호
# no1   강나래  구로고  197   90   85  100  85      Python
# 2번    강태원  구로고  184   40   35   50  25        Java
# 3번    강호림  가산고  168   80   75   70  75  Javascript
# 4번    김수찬  구로고  187   40   60   70  80         NaN
# 5번    김재욱  가산고  188   15   20   10  10         NaN
# 6번    박동현  가산고  202   80  100   95  80           C
# 7번    박혜정  구로고  188   55   65   45  35      PYTHON
# 8번    승근열  구로고  190  100   85   90  95          C#
